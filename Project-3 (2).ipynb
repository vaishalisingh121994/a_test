# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_table("/Users/nitin/Desktop/3077.dat")

# %%
df.head(10)
# Out:
#    1    1.1  2006-02-15 10:05:03
# 0  1   23.0  2006-02-15 10:05:03
# 1  1   25.0  2006-02-15 10:05:03
# 2  1  106.0  2006-02-15 10:05:03
# 3  1  140.0  2006-02-15 10:05:03
# 4  1  166.0  2006-02-15 10:05:03
# 5  1  277.0  2006-02-15 10:05:03
# 6  1  361.0  2006-02-15 10:05:03
# 7  1  438.0  2006-02-15 10:05:03
# 8  1  499.0  2006-02-15 10:05:03
# 9  1  506.0  2006-02-15 10:05:03

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the DataFrame with three separate vectors for the horizontal axis
data1 = pd.DataFrame({
    'X1': [2, 4, 6, 8, 10, 12],
    'Y1': [10, 15, 12, 17, 13, 16]
})

data2 = pd.DataFrame({
    'X2': [1, 2, 3, 4, 5, 6],
    'Y2': [11, 17, 14, 12, 19, 10]
})


data3 = pd.DataFrame({
    'X3': [3, 6, 9, 12, 15, 18],
    'Y3': [17, 13, 18, 12, 12, 18]
})




# Plotting the scatter plot
plt.scatter(data1['X1'], data1['Y1'], color='blue', label='Line 1')
plt.scatter(data2['X2'], data2['Y2'], color='purple', label='Line 2')
plt.scatter(data3['X3'], data3['Y3'], color='green', label='Line 3')

# Customize the plot
plt.xlabel('Horizontal Axis')
plt.ylabel('Vertical Axis')
plt.title('Scatter Plot with Multiple Lines')
plt.legend()

# Show the plot
plt.show()

# %%
# Sample data
category_amount = {
    'Category A': 10,
    'Category B': 12,
    'Category C': 15,
    'Category D': 8,
    'Category E': 2
}

# Extract category names and corresponding amounts
categories = list(category_amount.keys())
amounts = list(category_amount.values())

# Plotting the bar graph
plt.bar(categories, amounts)

# Customize the plot
plt.xlabel('Categories')
plt.ylabel('Amount')
plt.title('Bar Graph')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
#strings
my_string = 'fdfsdfsdfsdfsfd'
another_string = 'some string'
#ints
my_int = 5
another_int = 115
#floats
my_float = 20.17
another_float = 70.9
#booleans
my_bool = True
another_bool = False
yet_another_bool = (5 == 7)

# %%
# Length of the string
#print(len(my_string))

# Accessing individual characters using indexing
#print(my_string[0])     # Output: 'f'
#print(another_string[5])  # Output: 's'

# Slicing a string
#print(my_string[2:14])     # Output: 'fds'
#print(another_string[0:])  # Output: 'me string'

# Concatenating strings
#concatenated = my_string + another_string
#print(concatenated)       # Output: 'fdfsdfsdfsdfsfdsome string'
#print('abc'+'def')
# Converting to uppercase or lowercase
#print(my_string.upper())    # Output: 'FDFSDFSDFSDFSFD'
#print('ASAFD!&'.lower())  #
#print("doijhgjh".title())
# Checking if a string starts or ends with a specific substring
#print(my_string.startswith('fdfa'))   # Output: True
#print(another_string.endswith('ing'))  # Output: True

# Splitting a string into a list of substrings
#split_string = another_string.split('m')
#print(split_string)      # Output: ['some', 'string']

# Replacing substrings
#replaced_string = my_string.replace('fd', 'xyz')
#print(replaced_string)   # Output: 'xyzsdfsdfsdfsxyzsfd'

# Finding the index of a substring
#print(another_string.index('some'))   # Output: 5

# Counting occurrences of a substring
print(my_string.count('gfht'))   # Output: 2
# Out:
# 0

# %%
def sentiment_detection(sentence):
  positive = False
  negative = False
  for i in ('happy', 'people', 'makes','place','wonderful'):
    if sentence.count(i) > 0:
      positive = True
  for i in ('Empty','minds','place','of','devil'):
    if sentence.count(i) > 0:
      negative = True
  if positive == negative == False:
    return "neutral"
  elif positive == True != negative:
    return "positive"
  elif negative == True != positive:
    return 'negative'
  else:
    return "mixed"

# %%
sentiment_detection("It is devil")
# Out:
# 'negative'

# %%
sentiment_detection("It is wonderful")
# Out:
# 'positive'

# %%
sentiment_detection("It is place")
# Out:
# 'mixed'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16044 entries, 0 to 16043
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2                    16044 non-null  object
#  1   2005-05-24 22:54:33  16043 non-null  object
#  2   1525                 16043 non-null  float64
#  3   459                  16043 non-null  float64
#  4   2005-05-28 19:40:33  16043 non-null  object
#  5   1                    16043 non-null  float64
#  6   2006-02-16 02:30:53  16043 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 877.5+ KB

# %% [raw]
# SQL

# %%
SELECT f.rating, SUM(p.amount) AS total_revenue
FROM film f
JOIN inventory i ON f.film_id = i.film_id
JOIN rental r ON i.inventory_id = r.inventory_id
JOIN payment p ON r.rental_id = p.rental_id
GROUP BY f.rating
HAVING SUM(p.amount) > 13000
ORDER BY total_revenue DESC;
# Out:
#   Cell In[37], line 1
#     SELECT f.rating, SUM(p.amount) AS total_revenue
#            ^
# SyntaxError: invalid syntax

# %%
df.describe()
# Out:
#                1525           459             1
# count  16043.000000  16043.000000  16043.000000
# mean    2291.890357    297.133080      1.498909
# std     1322.237991    172.453776      0.500014
# min        1.000000      1.000000      1.000000
# 25%     1154.000000    148.000000      1.000000
# 50%     2291.000000    296.000000      1.000000
# 75%     3433.000000    446.000000      2.000000
# max     4581.000000    599.000000      2.000000

# %%
df.shape
# Out:
# (16044, 7)

# %%
df.shape[1]
# Out:
# 7

# %%
df.columns
# Out:
# Index(['2', '2005-05-24 22:54:33', '1525', '459', '2005-05-28 19:40:33', '1',
#        '2006-02-16 02:30:53'],
#       dtype='object')

# %%
df.columns[4]
# Out:
# '2005-05-28 19:40:33'

# %%
df.dtypes
# Out:
# 2                       object
# 2005-05-24 22:54:33     object
# 1525                   float64
# 459                    float64
# 2005-05-28 19:40:33     object
# 1                      float64
# 2006-02-16 02:30:53     object
# dtype: object

# %%
df_grouped=df.groupby('2005-05-24 22:54:33' )

# %%
df_grouped['2005-05-24 22:54:33'].describe()
# Out:
#                     count unique                  top freq
# 2005-05-24 22:54:33
# 2005-05-24 22:53:30     1      1  2005-05-24 22:53:30    1
# 2005-05-24 23:03:39     1      1  2005-05-24 23:03:39    1
# 2005-05-24 23:04:41     1      1  2005-05-24 23:04:41    1
# 2005-05-24 23:05:21     1      1  2005-05-24 23:05:21    1
# 2005-05-24 23:08:07     1      1  2005-05-24 23:08:07    1
# ...                   ...    ...                  ...  ...
# 2005-08-23 22:26:47     1      1  2005-08-23 22:26:47    1
# 2005-08-23 22:42:48     1      1  2005-08-23 22:42:48    1
# 2005-08-23 22:43:07     1      1  2005-08-23 22:43:07    1
# 2005-08-23 22:50:12     1      1  2005-08-23 22:50:12    1
# 2006-02-14 15:16:03   182      1  2006-02-14 15:16:03  182
#
# [15814 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

np.where([[True, False], [True, True]],
         [[1, 2], [3, 4]], [[5, 6], [7, 8]])
# Out:
# array([[1, 6],
#        [3, 4]])

# %%
# Python program explaining 
# where() function 
  
import numpy as np
  
# a is an array of integers.
a = np.array([[1, 2, 3], [4, 5, 6]])
  
print(a)
  
print ('Indices of elements <4')
  
b = np.where(a<4)
print(b)
  
print("Elements which are <4")
print(a[b])
# Out:
# [[1 2 3]
#  [4 5 6]]
# Indices of elements <4
# (array([0, 0, 0]), array([0, 1, 2]))
# Elements which are <4
# [1 2 3]

# %%
# Python program explaining
# numpy.select() function
  
# importing numpy as np 
import numpy as np
  
arr = np.arange(8)
  
condlist = [arr<3, arr>4]
choicelist = [arr, arr**3]
  
gfg = np.select(condlist, choicelist)
  
print (gfg)
# Out:
# [  0   1   2   0   0 125 216 343]

# %%
def f(x):return x * 2

f(3)
# Out:
# 6

# %%
lambda x: x * 3
# Out:
# <function __main__.<lambda>(x)>

# %%
lambda x:(x*2)*(3)
# Out:
# <function __main__.<lambda>(x)>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.DataFrame(
    {"name": ["IBRAHIM", "SEGUN", "YUSUF", "DARE", "BOLA", "SOKUNBI"],
     "score": [50, 32, 45, 45, 23, 45]
    }
)

# %%
df["lower_name"] = df["name"].apply(lambda x: x.lower())

# %%
adder = lambda x, y: x + y
print (adder (1, 2))
# Out:
# 3

# %%
x="some kind of a useless lambda"
(lambda x : print(x))(x)
# Out:
# some kind of a useless lambda

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x) 
  if x == "banana":
    break
# Out:
# apple
# banana

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    break
  print(x)
# Out:
# apple

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    continue
  print(x)
# Out:
# apple
# cherry

# %%
#Using the range() function:

for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(6):
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# Finally finished!

# %%
for x in range(6):
  if x == 3: break
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2

# %%
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

for x in adj:
  for y in fruits:
    print(x, y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %%
from pandas import read_csv
from matplotlib import pyplot
series = pd.read_table('/Users/nitin/Desktop/3077.dat', header=0, index_col=0, parse_dates=True, squeeze=True)

print(series.head())
# Out:
#    2005-05-24 22:54:33    1525    459  2005-05-28 19:40:33    1  \
# 2
# 3  2005-05-24 23:03:39  1711.0  408.0  2005-06-01 22:12:39  1.0
# 4  2005-05-24 23:04:41  2452.0  333.0  2005-06-03 01:43:41  2.0
# 5  2005-05-24 23:05:21  2079.0  222.0  2005-06-02 04:33:21  1.0
# 6  2005-05-24 23:08:07  2792.0  549.0  2005-05-27 01:32:07  1.0
# 7  2005-05-24 23:11:53  3995.0  269.0  2005-05-29 20:34:53  2.0
#
#    2006-02-16 02:30:53
# 2
# 3  2006-02-16 02:30:53
# 4  2006-02-16 02:30:53
# 5  2006-02-16 02:30:53
# 6  2006-02-16 02:30:53
# 7  2006-02-16 02:30:53
# /var/folders/_x/sq901qk10p34brjhdvxgp9840000gn/T/ipykernel_61770/538002062.py:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_table('/Users/nitin/Desktop/3077.dat', header=0, index_col=0, parse_dates=True, squeeze=True)

# %%
from pandas import read_csv
from matplotlib import pyplot
series = pd.read_table('/Users/nitin/Desktop/3077.dat', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot()
pyplot.show()
# Out:
# /var/folders/_x/sq901qk10p34brjhdvxgp9840000gn/T/ipykernel_61770/645129739.py:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_table('/Users/nitin/Desktop/3077.dat', header=0, index_col=0, parse_dates=True, squeeze=True)

# %%
from pandas import read_csv
from matplotlib import pyplot
series = pd.read_table('/Users/nitin/Desktop/3077.dat', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot(style='k.')
pyplot.show()
# Out:
# /var/folders/_x/sq901qk10p34brjhdvxgp9840000gn/T/ipykernel_61770/673284106.py:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_table('/Users/nitin/Desktop/3077.dat', header=0, index_col=0, parse_dates=True, squeeze=True)

# %%
from pandas import read_csv
from matplotlib import pyplot
series = pd.read_table('/Users/nitin/Desktop/3055.dat', header=0, index_col=0, parse_dates=True, squeeze=True)
series.hist()
pyplot.show()
# Out:
# /var/folders/_x/sq901qk10p34brjhdvxgp9840000gn/T/ipykernel_55132/2022374305.py:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_table('/Users/nitin/Desktop/3055.dat', header=0, index_col=0, parse_dates=True, squeeze=True)

# %%
from pandas import read_csv
from matplotlib import pyplot
series = pd.read_table('/Users/nitin/Desktop/3077.dat', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot(kind='kde')
pyplot.show()
# Out:
# /var/folders/_x/sq901qk10p34brjhdvxgp9840000gn/T/ipykernel_61770/2809810407.py:3: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_table('/Users/nitin/Desktop/3077.dat', header=0, index_col=0, parse_dates=True, squeeze=True)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 4
#       2 from matplotlib import pyplot
#       3 series = pd.read_table('/Users/nitin/Desktop/3077.dat', header=0, index_col=0, parse_dates=True, squeeze=True)
# ----> 4 series.plot(kind='kde')
#       5 pyplot.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:452, in MPLPlot.generate(self)
#     450 self._compute_plot_data()
#     451 self._setup_subplots()
# --> 452 self._make_plot()
#     453 self._add_table()
#     454 self._make_legend()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_matplotlib/hist.py:154, in HistPlot._make_plot(self)
#     151 if weights is not None and np.ndim(weights) != 1:
#     152     kwds["weights"] = weights[:, i]
# --> 154 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     156 # when by is applied, show title for subplots to know which group it is
#     157 if self.by is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_matplotlib/hist.py:232, in KdePlot._plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     220 @classmethod
#     221 def _plot(
#     222     cls,
#    (...)
#     230     **kwds,
#     231 ):
# --> 232     from scipy.stats import gaussian_kde
#     234     y = remove_na_arraylike(y)
#     235     gkde = gaussian_kde(y, bw_method=bw_method)
#
# ModuleNotFoundError: No module named 'scipy'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('tips')
sns.barplot(x = 'time',y = 'total_bill',data = df)
plt.show()

# %%
# Create a new data-frame where you classify some different countries into some categories that make sense to you
# (8 countries min, 20 max) in this df there will be two columns, one column will give the country name, 
# the other column will give the classification category.countries_data = {
   
    
countries_data = {
    'country': ['US', 'UK', 'Ca', 'Aust', 'Ger', 'Fran', 'Braz', 'In', 'China', 'Japan'],
    'Geographical Location': ['NA', 'Eur', 'NA', 'Oceania', 'Eur', 'Eur', 'SA', 'Asia', 'Asia', 'Asia']
}

df = pd.DataFrame(countries_data)

location_counts = df['Geographical Location'].value_counts()

plt.pie(location_counts.values, labels=location_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Countries by Geographical Location')
plt.axis('equal')
plt.show()
